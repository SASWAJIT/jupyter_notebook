# %%
import matplotlib.pyplot as plt
l=[5,3,6,7,2,8,9,44,15,16,19,17,12,14,18]
plt.boxplot(l)
plt.show()

# %%
import matplotlib.pyplot as plt
l=[5,3,6,7,2,8,9,44,15,16,19,17,12,14,18]
l1=[4,5,16,51,22,7,8,1,2,3,5,4,6,7,8,14]
plt_values=[l,l1]
plt.boxplot(plt_values)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_excel("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/expense3.xlsx")
df=pd.DataFrame(data)
#print(df)
plt.boxplot(df["Amount"])
plt.show()
