# %%
import matplotlib.pyplot as plt
x=[30,21,12,14,9,8,8,7,27,2,64,3,39,0]
plt.hist(x,bins=30,edgecolor='black',color='pink')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_excel("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/ESD.xlsx")
df=pd.DataFrame(data)
#print(df)
plt.hist(df["Age"],bins=20,edgecolor='black',color='green')
plt.show()
