# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[30,40,25,30,40]
y1=[30,28,32,29,34]
y2=[24,26,30,37,32]
y3=[34,22,18,16,24]
plt.plot(x,y,label='Male')
plt.plot(x,y1,label='Female')
plt.plot(x,y2,label='child')
plt.plot(x,y3,label='Blanked')
plt.legend(bbox_to_anchor=(0.8,1.2),ncols=2,labelspacing=2)
plt.show()
