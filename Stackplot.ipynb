# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5,6,7]
NOP1=[5,10,30,20,35,60,80]
NOP2=[50,60,30,75,80,90,120]
NOP3=[8,30,50,60,70,90,100]
plt.stackplot(days,NOP1,NOP2,NOP3)
plt.show()

# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5,6,7]
NOP1=[5,10,30,20,35,60,80]
NOP2=[50,60,30,75,80,90,120]
NOP3=[8,30,50,60,70,90,100]
plt.stackplot(days,NOP1,NOP2,NOP3,baseline='wiggle',labels=['week1','week2','week3'])
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/food_data.csv")
df=pd.DataFrame(data)
print(df)
# grouped=df.groupby("Category")['Calories','Protein','Fat'].agg("mean")
# print(grouped)
# Out:
#       Calories  Protein   Fat  Carbs  Fibre  Unnamed: 5  \
# 0           73      2.0   NaN   16.0    0.4         NaN
# 1          129      3.0   NaN   29.0    0.1         NaN
# 2           45      1.0   1.0    7.0    0.2         NaN
# 3          206      2.0   4.0   39.0    1.8         NaN
# 4          296      2.0  14.0   43.0    2.0         NaN
# ...        ...      ...   ...    ...    ...         ...
# 1089        22      2.0   NaN    4.0    2.4         NaN
# 1090        63      3.0   NaN   13.0    2.8         NaN
# 1091        51      3.0   NaN   11.0    2.7         NaN
# 1092         6      NaN   NaN    1.0    0.4         NaN
# 1093        15      1.0   NaN    4.0    1.3         NaN
#
#       Note: Protein, Fat, Carbs, Fibre, are measured in grams
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...
