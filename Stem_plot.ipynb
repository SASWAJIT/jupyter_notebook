# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,30,56,62,70,80,90,60]
plt.stem(x,linefmt="--",markerfmt="D",bottom=10,orientation='horizontal',label="Expense")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_excel("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/ESD.xlsx")
df=pd.DataFrame(data)
df2=df.head(50)
#print(df)
plt.stem(df2["Age"])
plt.plot(df2["Age"])
plt.show()
