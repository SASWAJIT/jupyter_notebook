# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[30,40,25,30,40]
plt.step(x,y,where='post',marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_excel("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/expense3.xlsx")
df=pd.DataFrame(data)
#print(df)
group = df.groupby('Category').agg({'Amount': 'sum'})
group2=df.groupby('Category')['Amount'].mean()
# print(group2)
print(group)
plt.step(df["Category"].unique(),group['Amount'],where='mid',marker='o')
plt.show()
# Out:
#             Amount
# Category
# Bills        18724
# Clothes       2890
# Essentials    4485
# Food          3022
# Grocery       1028
