# %%
import matplotlib.pyplot as plt
x=[98,67,88,95,88]
y=['p1','p2','p3','p4','p5']
colors=['red','black','brown','yellow','blue']
plt.bar(y,x,color=colors)
plt.xlabel("parts of Harry porter",fontsize=17)
plt.ylabel('popularity',fontsize=17)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_excel("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/expense3.xlsx")
df=pd.DataFrame(data)
print(df)
plt.bar(df["Department"],df["Annual Salary"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 3
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 3 data=pd.read_excel("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/expense3.xlsx")
#       4 df=pd.DataFrame(data)
#       5 print(df)
#
# File ~\miniconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...
