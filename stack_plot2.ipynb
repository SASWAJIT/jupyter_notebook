# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
NOP1=[10,12,20,17,18]
NOP2=[21,25,23,27,28]
NOP3=[12,20,21,25,16]
plt.stackplot(days,NOP1,NOP2,NOP3)
plt.show()

# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
NOP1=[10,12,20,17,18]
NOP2=[21,25,23,27,28]
NOP3=[12,20,21,25,16]
plt.stackplot(days,NOP1,NOP2,NOP3,baseline='wiggle',colors=['pink','hotpink','magenta'])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/food_data.csv")
df=pd.DataFrame(data)
df2=df.head(50)
print(df2)
grouped=df.group_by('')
# Out:
#     Calories  Protein   Fat  Carbs  Fibre  Unnamed: 5  \
# 0         73      2.0   NaN   16.0    0.4         NaN
# 1        129      3.0   NaN   29.0    0.1         NaN
# 2         45      1.0   1.0    7.0    0.2         NaN
# 3        206      2.0   4.0   39.0    1.8         NaN
# 4        296      2.0  14.0   43.0    2.0         NaN
# 5        411      4.0  19.0   58.0    2.3         NaN
# 6        196      3.0   6.0   33.0    0.7         NaN
# 7        231      3.0  12.0   29.0    0.6         NaN
# 8        186      3.0   8.0   25.0    0.7         NaN
# 9         97      2.0   4.0   14.0    0.4         NaN
# 10       212      4.0  10.0   27.0    0.9         NaN
# 11        93      2.0   4.0   13.0    0.4         NaN
# 12       232      2.0   8.0   39.0    1.3         NaN
# 13       162      6.0   5.0   24.0    0.9         NaN
# 14       197      3.0   5.0   33.0    2.4         NaN
# 15       138      2.0   6.0   22.0    0.7         NaN
# 16       168      2.0  10.0   18.0    0.8         NaN
# 17       248      2.0  14.0   29.0    0.7         NaN
# 18       542      5.0  28.0   70.0    1.5         NaN
# 19       135      2.0   3.0   26.0    1.2         NaN
# 20       321      6.0  23.0   26.0    0.4         NaN
# 21       407      8.0  19.0   53.0    2.8         NaN
# 22       459     11.0  23.0   55.0    0.8         NaN
# 23       325      3.0  14.0   50.0    1.0         NaN
# 24        98      1.0   5.0   13.0    0.6         NaN
# 25       156      2.0   9.0   19.0    0.9         NaN
# 26       118      1.0   5.0   16.0    0.4         NaN
# 27       129      1.0   4.0   21.0    0.6         NaN
# 28       344      3.0  22.0   38.0    2.3         NaN
# 29        93      1.0   4.0   14.0    0.6         NaN
# 30       362      4.0  13.0   61.0    2.0         NaN
# 31       282      3.0  10.0   48.0    2.0         NaN
# 32       408      4.0  16.0   67.0    1.9         NaN
# 33       191      1.0  11.0   24.0    0.8         NaN
# 34       194      2.0   6.0   35.0    0.9         NaN
# 35       237      4.0  13.0   26.0    1.1         NaN
# 36       142      2.0   4.0   24.0    0.5         NaN
# 37       231      5.0  12.0   26.0    1.5         NaN
# 38       262      5.0  15.0   29.0    0.8         NaN
# 39       263      4.0  13.0   34.0    1.3         NaN
# 40       226      3.0   8.0   37.0    2.3         NaN
# 41       198      2.0  11.0   23.0    0.7         NaN
# 42       270      3.0  18.0   27.0    1.1         NaN
# 43       242      4.0  14.0   27.0    0.7         NaN
# 44       289      5.0  16.0   33.0    0.8         NaN
# 45       262      6.0  16.0   24.0    0.6         NaN
# 46       111      1.0   2.0   23.0    1.5         NaN
# 47       404      4.0  21.0   55.0    3.3         NaN
# 48       139      1.0   4.0   26.0    1.6         NaN
# 49        58      1.0   1.0   11.0    0.3         NaN
#
#     Note: Protein, Fat, Carbs, Fibre, are measured in grams
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20932\2351948414.py in ?()
#       3 data=pd.read_csv("C:/Users/saswa/OneDrive/Desktop/coding.python/Data Analytics/Jupyter notebook/food_data.csv")
#       4 df=pd.DataFrame(data)
#       5 df2=df.head(50)
#       6 print(df2)
# ----> 7 grouped=df.group_by('')
#
# ~\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'
